# %%
from model import Watch, Listen, Spell
from torch import nn, optim
import os
import cv2
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from train import train
from dataLoader import videoDataset, to_int, txtProcess
from torch.utils.data import Dataset, DataLoader

# %%
watch = Watch(3, 512, 256)
listen = Listen(3, 256)
spell = Spell(num_layers=3, output_size=43, hidden_size=512)

watch_optimizer = optim.Adam(watch.parameters(),
                lr=0.01)
listen_optimizer = optim.Adam(listen.parameters(),
                lr=0.01)
spell_optimizer = optim.Adam(spell.parameters(),
                lr=0.01)
criterion = nn.CrossEntropyLoss(ignore_index=38)

dataset = videoDataset('sample/', 160, 120)
train_loader = DataLoader(dataset=dataset,
                    batch_size=7,
                    shuffle=True)
total_batch = len(train_loader)

for epoch in range(50):
    avg_loss = 0.0

    for i, (data, labels) in enumerate(train_loader):
        loss = train(data, labels,
                     watch, listen, spell,
                     watch_optimizer, listen_optimizer, spell_optimizer,
                     criterion)
        avg_loss += loss
        
    print('epoch:', epoch, ' train_loss:', float(avg_loss/total_batch))
# Out:
# /Users/sangroklee/Desktop/lipmodel/model.py:186: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   alpha = F.softmax(attn_energies).unsqueeze(1)
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# epoch: 0  train_loss: 2.8519602457682294
# E
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# T
# ...
